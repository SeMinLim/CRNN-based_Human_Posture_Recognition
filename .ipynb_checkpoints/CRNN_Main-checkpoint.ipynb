# %% [markdown]
# # CRNN-based Human Posture Recognition in Video Data

# %% [markdown]
# ### Summary of the session

# %% [markdown]
# - 1. **Dataset extraction**
# - 2. **Frames features extraction**
#     - 2.a. RGB features
#     - 2.b. Transfer learning of pretrained CNN models
# - 3. **Unsupervised learning**
#     - 3.a. Average pooling
#     - 3.b. LSTM autoencoders
# - 4. **Supervised learning: video classification**
#     - 4.a. Average pooling
#     - 4.b. RNN : LSTM

# %% [markdown]
# # 1. Dataset extraction

# %% [markdown]
# ### Requirements

# %% [markdown]
# - **Setup**:
#     - **tensorflow==2.0**
#     - keras==2.3.1
#     - cv2==4.1.1

# %% [markdown]
# ### Imports

# %%
# general import
import os
import math   
from tqdm import tqdm
import matplotlib.pyplot as plt    
# %matplotlib inline
from IPython.display import Image
import numpy as np    
import pandas as pd

# ML import
from sklearn.preprocessing import LabelBinarizer

# images import
import cv2     # opencv, need to be installed with pip install opencv-python
from keras.preprocessing import image
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### Extracting and saving the frames for train and test set

# %% [markdown]
# In this section, we will **extract the frames (jpg format)** of the videos and **save** them for later use.

# %%
def get_video_names(task):
    
    """
    This function returns the video filepaths 
    for the given set ("train" or "test")
    """
    
    f = open("TrainTestlist/"+task+"list.txt", "r")
    temp = f.read()
    videos = temp.split('\n')[:-1]
    videos = ["Data/"+video.split(' ')[0] for video in videos]
    
    return videos

# %%
def extract_frames(task, videos):
    
    """
    This function will extract & save the frames for 
    a given list of video filepaths 
    """
    
    # creating the repo 
    try:
        os.mkdir(task)
    except:
        pass
    
    # extracting the frames from the videos
    frames = []
    targets = []

    for video in tqdm(videos):
        video_frames = []
        count = 0
        cap = cv2.VideoCapture(video)   # capturing the video from the given path
        frameRate = cap.get(5) #frame rate
        x=1
        while(cap.isOpened()):
            frameId = cap.get(1) # current frame number
            ret, frame = cap.read()
            if (ret != True):
                break
            if (frameId % math.floor(frameRate) == 0):
                # storing the frames in the task folder 
                filename = task + '/' + video.split("/")[-1] +"_frame%d.jpg" % count;count+=1
                cv2.imwrite(filename, frame)
                video_frames.append(filename)

        frames.append(video_frames)
        targets.append(video.split("_")[-4])

        cap.release()

    # now saving information into a file
    data = pd.DataFrame()
    data['videos'] = videos
    data["frames"] = frames
    data["targets"] = targets
    
    return data

# %% [markdown]
# **we run the frames extraction for train and test sets**: JPG images will be saved in *train* and *test* folders.

# %% [markdown]
# **[DO NOT RUN]**

# %%
for task in ["train", "test"]:
    
    print(task)
    
    videos = get_video_names(task)
    print(videos[:3])
    
    dataset = extract_frames(task, videos)
    dataset.to_json(task+'.json')
# Out:
#   0%|          | 0/112 [00:00<?, ?it/s]
# train
# ['Data/v_1st_Expert_1_1.mp4', 'Data/v_1st_Expert_1_2.mp4', 'Data/v_1st_Expert_1_3.mp4']
# 100%|██████████| 112/112 [01:09<00:00,  1.62it/s]
#   0%|          | 0/48 [00:00<?, ?it/s]
# test
# ['Data/v_1st_Expert_1_8.mp4', 'Data/v_1st_Expert_1_9.mp4', 'Data/v_1st_Expert_1_10.mp4']
# 100%|██████████| 48/48 [00:29<00:00,  1.61it/s]

# %% [markdown]
# # 2. Frames feature extraction

# %% [markdown]
# The purpose of this section is to **extract relevant features for each frame** of a video.
#
# For each video, we first load the JPG images extracted in the previous section and then we **compute features for each frame using a pretrained convolutional neural network** (eg : Inception-v3, VGG16, ...) .
#
# We will also **binarize** our target (4 classes).

# %% [markdown]
# #### Load the dataset information

# %%
train = pd.read_json("train.json")

# %%
train.targets.value_counts()
# Out:
# 2nd    28
# 3rd    28
# 1st    28
# 4th    28
# Name: targets, dtype: int64

# %%
train.frames.apply(len).describe()
# Out:
# count    112.000000
# mean      13.526786
# std        1.879044
# min        9.000000
# 25%       12.750000
# 50%       14.000000
# 75%       15.000000
# max       17.000000
# Name: frames, dtype: float64

# %%
train.frames.apply(len).sum()
# Out:
# 1515

# %%
train.head()
# Out:
#                       videos  \
# 0  Data/v_1st_Expert_1_1.mp4
# 1  Data/v_1st_Expert_1_2.mp4
# 2  Data/v_1st_Expert_1_3.mp4
# 3  Data/v_1st_Expert_1_4.mp4
# 4  Data/v_1st_Expert_1_5.mp4
#
#                                               frames targets
# 0  [train/v_1st_Expert_1_1.mp4_frame0.jpg, train/...     1st
# 1  [train/v_1st_Expert_1_2.mp4_frame0.jpg, train/...     1st
# 2  [train/v_1st_Expert_1_3.mp4_frame0.jpg, train/...     1st
# 3  [train/v_1st_Expert_1_4.mp4_frame0.jpg, train/...     1st
# 4  [train/v_1st_Expert_1_5.mp4_frame0.jpg, train/...     1st

# %% [markdown]
# ## 2.a. RGB features

# %% [markdown]
# We will extract the **RGB** features for each frames of a video. Each frame is a 3D-tensor of size (n_pixels, n_pixels, 3). So each pixel is encoded with 3 features : **Red**, **Green** and **Blue** colors.

# %%
def load_images(files):
    
    """
    This function loads RGB features of a given image
    """
    
    images = []
    
    for f in files:

        img = image.load_img(f, target_size=(224,224,3))
        img = image.img_to_array(img)
        img = img/255
        
        images.append(img)
        
    return np.array(images)

# %%
files = train.frames.iloc[10]
len(files)
# Out:
# 15

# %%
rgb = load_images(files)
rgb[0].shape
# Out:
# (224, 224, 3)

# %%
rgb[0][100, 100]
# Out:
# array([0.87058824, 0.8666667 , 0.8509804 ], dtype=float32)

# %% [markdown]
# ## 2.b. Transfer learning of pretrained CNN models

# %% [markdown]
# We will use **Inception-v3** convolutional neural network which was pretrained on ImageNet to compute relevant features (edges, shapes, ...) **for each frame**. There exists several other pretrained CNN models (VGG16, ...) which can be tested easily by adapting the following code.

# %% [markdown]
# we load Inception-V3 model...

# %%
from tensorflow.keras.applications.inception_v3 import InceptionV3

feature_extractor = InceptionV3(weights='imagenet', include_top=False, pooling="avg")
# Out:
# A local file was found, but it seems to be incomplete or outdated because the auto file hash does not match the original value of bcbd6486424b2319ff4ef7d526e38f63 so we will re-download the data.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87916544/87910968 [==============================] - 220s 3us/step

# %% [markdown]
# we also prepare our target for later use...

# %%
binarizer = LabelBinarizer()
classes = train.targets.unique()
binarizer.fit(classes)
# Out:
# LabelBinarizer()

# %% [markdown]
# **Now, we define a function that will:**
#
# - **load** the images and extract **RGB features**
# - compute **Inception-v3 average pooling representations** for each one
# - **binarize** the labels

# %%
def compute_batch_record(batch_data, feature_extractor, binarizer):
    
    """
    This function runs the frames extraction (RGB) & frames feature 
    extraction and binarize the target for data batch.
    """
    
    n_videos = len(batch_data)
    
    # extract the frames for the video batch
    print("extracting the frames for {} videos...".format(n_videos))
    
    frames = np.concatenate([load_images(batch_data.frames.iloc[v]) 
                             for v in tqdm(range(n_videos))])
    
    # extract the features
    print("computing the features for {} videos...".format(n_videos))
    features = feature_extractor.predict(frames)
    
    # regroup per video
    embeddings = []
    
    index = 0 
    
    for v in range(n_videos):
        
        n_images = len(batch_data.frames.iloc[v])
                                
        embeddings.append(features[index : index+n_images])
        
        index += n_images
        
    # binarize the target
    labels = binarizer.transform(batch_data.targets).tolist()

    return (
        list(batch_data.videos), 
        embeddings, 
        list(batch_data.targets),
        labels
    )

# %% [markdown]
# **we run the frames features extraction for some samples :**

# %%
n_sample = 50
# %time record = compute_batch_record(train.sample(n_sample), feature_extractor, binarizer)
# Out:
#   2%|▏         | 1/50 [00:00<00:05,  9.73it/s]
# extracting the frames for 50 videos...
# 100%|██████████| 50/50 [00:04<00:00, 10.84it/s]
# computing the features for 50 videos...
# CPU times: user 1min 36s, sys: 2.67 s, total: 1min 39s
# Wall time: 18.9 s

# %% [markdown]
# **NOTE**: each image with initial shape (224, 224, 3) **will be now encoded into a 1D tensor of shape (2048, )** :

# %%
record[1][0][0].shape
# Out:
# (2048,)

# %% [markdown]
# # 3. Unsupervised learning (or video feature extraction)

# %% [markdown]
# Videos can now be considered as multi-dimensional time series. The purpose of this section is to find a "relevant" **1D-tensor representation of the videos.**

# %% [markdown]
# ## 3.a. Average pooling representation

# %% [markdown]
# We just **average the features** of each frame to get the video representation

# %%
n_sample = 100
# %time record = compute_batch_record(train.sample(n_sample), feature_extractor, binarizer)
# Out:
#   1%|          | 1/100 [00:00<00:10,  9.11it/s]
# extracting the frames for 100 videos...
# 100%|██████████| 100/100 [00:09<00:00, 10.68it/s]
# computing the features for 100 videos...
# CPU times: user 3min 15s, sys: 5.08 s, total: 3min 20s
# Wall time: 34.5 s

# %%
X = np.array([np.mean(record[1][i], axis=0) for i in range(len(record[1]))])

# %%
X.shape
# Out:
# (100, 2048)

# %% [markdown]
# #### 2D projection of representation

# %% [markdown]
# Once we get a 1D-tensor representation for each video, we can **display our videos** in 2D (using standard dimension reduction algorithms like PCA, t-SNE, ...)

# %%
from sklearn.manifold import TSNE
from sklearn.neighbors import NearestNeighbors
import matplotlib.pyplot as plt

tsne = TSNE(n_components=2)

X_tnse = tsne.fit_transform(X)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 7))

classes = np.unique(record[2])

for c in classes:
    i = np.where(np.array(record[2])==c)[0]
    plt.plot(X_tnse[i,0], X_tnse[i,1], 'o')

# %% [markdown]
# #### Consistency and relevance

# %% [markdown]
# For a given random video, we check **if the nearest videos are similar**

# %%
nn = NearestNeighbors()
nn.fit(X)
# Out:
# NearestNeighbors()

# %% [markdown]
# we choose a random video:

# %%
from IPython.display import Image

v = np.random.choice(len(record[0]), 1)[0]  # we choose a random video
video_name = record[0][v]

img = train[train.videos==video_name].frames.iloc[0][0]

print(record[0][v])
Image(img)
# Out:
# Data/v_4th_Expert_2_5.mp4

# %% [markdown]
# we compute the neighbors:

# %%
neighbors = nn.kneighbors([X[v]])[1][0][1:]

# %% [markdown]
# we display the nearest video:

# %%
print(record[0][neighbors[0]])
img = train[train.videos==record[0][neighbors[0]]].frames.iloc[0][0]
Image(img)
# Out:
# Data/v_4th_Expert_2_4.mp4

# %% [markdown]
# we check the categories of the top-4 nearest videos:

# %%
for i in neighbors:
    print(record[0][i])
# Out:
# Data/v_4th_Expert_2_4.mp4
# Data/v_4th_Expert_2_1.mp4
# Data/v_4th_Expert_2_6.mp4
# Data/v_4th_Expert_2_3.mp4

# %% [markdown]
# **we compute top1 & top2 accuracy**

# %%
a1 = 0
a2 = 0
n = len(record[0])

for v in range(len(record[0])):
    
    video_name = record[0][v]  
    category = train[train.videos==video_name].targets.iloc[0]
    
    neighbors = nn.kneighbors([X[v]])[1][0][1:]
    
    category1 = train[train.videos==record[0][neighbors[0]]].targets.iloc[0]
    category2 = train[train.videos==record[0][neighbors[1]]].targets.iloc[0]

    if category==category1:
        a1+=1/n
    if category==category1 or category==category2:
        a2+=1/n

# %%
print("top1-accuracy", a1)
print("top2-accuracy", a2)
# Out:
# top1-accuracy 1.0000000000000007
# top2-accuracy 1.0000000000000007

# %% [markdown]
# ## 3.b. LSTM auto-encoders

# %% [markdown]
# Unlike the average pooling, the LSTM auto-encoder take into account the **sequential order of the frames**. In this version, the **encoder** encodes the sequence of frames into a fixed-length vector (here 2048) and the **decoder** tries to decode it to recreate the input sequence **with minimum error**. Once the architecture is fitted, we can remove the decoder and use the encoder to get the representation of a video.

# %% [markdown]
# ### video preparation

# %% [markdown]
# #### train and test information loading

# %%
dataset = dict()

for task in ["train", "test"]:
    dataset[task] = pd.read_json("{}.json".format(task))

# %% [markdown]
# #### cropping and 0-padding

# %% [markdown]
# we **crop** the videos (we keep 10 frames) and for shorter videos, we **pad missing frames with value "0"**

# %%
def crop(embeddings, cut=10):
    
    """
    This function crops and pads the multi-dimensional sequential 
    representations of the videos.
    """
    
    print("padding...")
    
    cropped_embeddings = []
    
    for x in embeddings:
        
        n_pad = cut - len(x[:cut])
        
        x_crop = np.pad(x[:cut], 
                        [(0, n_pad), (0, 0)], 
                        'constant',
                        constant_values=0)
        
        cropped_embeddings.append(x_crop)
    
    return cropped_embeddings

# %% [markdown]
# #### (Sequential) TF records

# %% [markdown]
# We define a function that will write **TF-records** of video batches. We will use this format to fit our LSTM auto-encoder for **low memory usage** (as video batches will be loaded on-the-fly while fitting the neural network) ! As a video is a sequential type of data (like time series), we save our tf records using *tf.train.SequenceExample*

# %%
def write_seqtfrecords(filepath, data):
    
    """
    This function writes the sequential tf-records, with keys:
    - video filenames 
    - video categories 
    - video binarized categories 
    - video embeddings for each frames
    """

    print("writting {}...".format(filepath))

    writer = tf.io.TFRecordWriter(filepath)

    for i in range(len(data[0])):
        
        # context 
        features = dict()
        
        features["videos"] = tf.train.Feature(
            bytes_list=tf.train.BytesList(value=[str.encode(data[0][i])])
        )
        features["targets"] = tf.train.Feature(
            bytes_list=tf.train.BytesList(value=[str.encode(data[2][i])])
        )
        features["labels"] = tf.train.Feature(
            int64_list=tf.train.Int64List(value=data[3][i])
        )

        # feature_lists
        E = [tf.train.FloatList(value=data[1][i][t,:].tolist()) 
             for t in range(data[1][i].shape[0])]
            
        embedding = tf.train.FeatureList(feature=[
            tf.train.Feature(float_list=e) for e in E])

        # sequence
        example = tf.train.SequenceExample(
            context=tf.train.Features(feature=features),
            feature_lists=tf.train.FeatureLists(feature_list={
                "embeddings": embedding
        }))
        
        writer.write(example.SerializeToString())

    writer.close()

# %%
def compute_tf_records(dataset, task, feature_extractor, binarizer, batch_size=4, cut=10):
    
    """
    This function runs the tf-records computation and writes them in the 
    folder preprocess.
    """
    
    data = dataset[task]
    data = data.sample(data.shape[0])
    
    n_batch = int(data.shape[0]/batch_size)+1

    for batch in tqdm(range(n_batch)):
    
        # compute batch record
        a = batch*batch_size
        b = min((batch+1)*batch_size, data.shape[0])

        (videos, embeddings, targets, labels) = compute_batch_record(data.iloc[a:b], 
                                                                     feature_extractor, 
                                                                     binarizer)

        # crop
        embeddings = crop(embeddings, cut)

        # write tf record 
        filepath = "preprocess/{}/seq_{}.tfrecord".format(task, batch)
        write_seqtfrecords(filepath, (videos, embeddings, targets, labels))

# %% [markdown]
# **we run the writting of TF records for train and test sets**: it will be saved in *preprocess/train* and *preprocess/test* folders.

# %% [markdown]
# **[DO NOT RUN]**

# %%
batch_size=160

for task in ["train", "test"]:
    print(task)
    compute_tf_records(dataset, task, feature_extractor, binarizer, batch_size=batch_size, cut=10)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/112 [00:00<?, ?it/s]
#   1%|          | 1/112 [00:00<00:11,  9.73it/s]
# train
# extracting the frames for 112 videos...
#   3%|▎         | 3/112 [00:00<00:11,  9.89it/s]
#   4%|▍         | 5/112 [00:00<00:10, 10.07it/s]
#   6%|▋         | 7/112 [00:00<00:09, 10.58it/s]
#   8%|▊         | 9/112 [00:00<00:09, 10.47it/s]
#   9%|▉         | 10/112 [00:00<00:10,  9.95it/s]
#  10%|▉         | 11/112 [00:01<00:11,  8.93it/s]
#  12%|█▏        | 13/112 [00:01<00:10,  9.67it/s]
#  12%|█▎        | 14/112 [00:01<00:10,  9.53it/s]
#  13%|█▎        | 15/112 [00:01<00:10,  9.11it/s]
#  14%|█▍        | 16/112 [00:01<00:10,  9.32it/s]
#  15%|█▌        | 17/112 [00:01<00:09,  9.51it/s]
#  16%|█▌        | 18/112 [00:01<00:10,  9.25it/s]
#  17%|█▋        | 19/112 [00:01<00:10,  9.02it/s]
#  18%|█▊        | 20/112 [00:02<00:10,  9.14it/s]
#  20%|█▉        | 22/112 [00:02<00:09,  9.61it/s]
#  21%|██        | 23/112 [00:02<00:09,  9.67it/s]
#  21%|██▏       | 24/112 [00:02<00:09,  9.60it/s]
#  23%|██▎       | 26/112 [00:02<00:08,  9.63it/s]
#  24%|██▍       | 27/112 [00:02<00:08,  9.57it/s]
#  26%|██▌       | 29/112 [00:02<00:08, 10.27it/s]
#  28%|██▊       | 31/112 [00:03<00:08,  9.97it/s]
#  29%|██▉       | 33/112 [00:03<00:07, 10.28it/s]
#  31%|███▏      | 35/112 [00:03<00:07, 10.15it/s]
#  33%|███▎      | 37/112 [00:03<00:07, 10.24it/s]
#  35%|███▍      | 39/112 [00:03<00:07, 10.20it/s]
#  37%|███▋      | 41/112 [00:04<00:06, 10.36it/s]
#  38%|███▊      | 43/112 [00:04<00:06, 10.54it/s]
#  40%|████      | 45/112 [00:04<00:06, 10.65it/s]
#  42%|████▏     | 47/112 [00:04<00:05, 10.93it/s]
#  44%|████▍     | 49/112 [00:04<00:05, 11.30it/s]
#  46%|████▌     | 51/112 [00:04<00:05, 11.22it/s]
#  47%|████▋     | 53/112 [00:05<00:05, 11.63it/s]
#  49%|████▉     | 55/112 [00:05<00:04, 11.53it/s]
#  51%|█████     | 57/112 [00:05<00:04, 11.17it/s]
#  53%|█████▎    | 59/112 [00:05<00:04, 10.63it/s]
#  54%|█████▍    | 61/112 [00:05<00:04, 11.24it/s]
#  56%|█████▋    | 63/112 [00:06<00:04, 11.39it/s]
#  58%|█████▊    | 65/112 [00:06<00:04, 10.76it/s]
#  60%|█████▉    | 67/112 [00:06<00:04, 10.30it/s]
#  62%|██████▏   | 69/112 [00:06<00:04, 10.15it/s]
#  63%|██████▎   | 71/112 [00:06<00:04,  9.77it/s]
#  64%|██████▍   | 72/112 [00:06<00:04,  9.33it/s]
#  65%|██████▌   | 73/112 [00:07<00:04,  9.41it/s]
#  66%|██████▌   | 74/112 [00:07<00:04,  9.40it/s]
#  68%|██████▊   | 76/112 [00:07<00:03,  9.85it/s]
#  69%|██████▉   | 77/112 [00:07<00:03,  9.73it/s]
#  70%|██████▉   | 78/112 [00:07<00:03,  9.49it/s]
#  71%|███████   | 79/112 [00:07<00:03,  9.23it/s]
#  71%|███████▏  | 80/112 [00:07<00:03,  9.16it/s]
#  73%|███████▎  | 82/112 [00:08<00:03,  9.33it/s]
#  74%|███████▍  | 83/112 [00:08<00:03,  9.34it/s]
#  75%|███████▌  | 84/112 [00:08<00:02,  9.45it/s]
#  76%|███████▌  | 85/112 [00:08<00:02,  9.33it/s]
#  78%|███████▊  | 87/112 [00:08<00:02,  9.55it/s]
#  79%|███████▉  | 89/112 [00:08<00:02,  9.80it/s]
#  81%|████████▏ | 91/112 [00:08<00:02, 10.10it/s]
#  83%|████████▎ | 93/112 [00:09<00:01, 10.79it/s]
#  85%|████████▍ | 95/112 [00:09<00:01, 10.54it/s]
#  87%|████████▋ | 97/112 [00:09<00:01, 10.82it/s]
#  88%|████████▊ | 99/112 [00:09<00:01, 11.09it/s]
#  90%|█████████ | 101/112 [00:09<00:01, 10.87it/s]
#  92%|█████████▏| 103/112 [00:10<00:00, 10.44it/s]
#  94%|█████████▍| 105/112 [00:10<00:00, 10.56it/s]
#  96%|█████████▌| 107/112 [00:10<00:00, 11.32it/s]
#  97%|█████████▋| 109/112 [00:10<00:00, 10.51it/s]
# 100%|██████████| 112/112 [00:10<00:00, 10.31it/s]
# computing the features for 112 videos...
# padding...
# writting preprocess/train/seq_0.tfrecord...
# 100%|██████████| 1/1 [00:40<00:00, 40.48s/it]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/48 [00:00<?, ?it/s]
#   2%|▏         | 1/48 [00:00<00:05,  8.98it/s]
# test
# extracting the frames for 48 videos...
#   6%|▋         | 3/48 [00:00<00:04,  9.67it/s]
#  10%|█         | 5/48 [00:00<00:04, 10.07it/s]
#  15%|█▍        | 7/48 [00:00<00:04, 10.15it/s]
#  19%|█▉        | 9/48 [00:00<00:03, 10.60it/s]
#  23%|██▎       | 11/48 [00:01<00:03, 10.61it/s]
#  25%|██▌       | 12/48 [00:01<00:03,  9.78it/s]
#  27%|██▋       | 13/48 [00:01<00:03,  9.75it/s]
#  29%|██▉       | 14/48 [00:01<00:03,  9.64it/s]
#  31%|███▏      | 15/48 [00:01<00:03,  9.62it/s]
#  35%|███▌      | 17/48 [00:01<00:03, 10.13it/s]
#  40%|███▉      | 19/48 [00:01<00:02,  9.97it/s]
#  44%|████▍     | 21/48 [00:02<00:02, 10.09it/s]
#  48%|████▊     | 23/48 [00:02<00:02,  9.52it/s]
#  52%|█████▏    | 25/48 [00:02<00:02, 10.10it/s]
#  56%|█████▋    | 27/48 [00:02<00:02, 10.25it/s]
#  60%|██████    | 29/48 [00:02<00:01, 10.34it/s]
#  65%|██████▍   | 31/48 [00:02<00:01, 10.65it/s]
#  69%|██████▉   | 33/48 [00:03<00:01, 10.28it/s]
#  73%|███████▎  | 35/48 [00:03<00:01, 10.68it/s]
#  77%|███████▋  | 37/48 [00:03<00:01,  9.93it/s]
#  81%|████████▏ | 39/48 [00:03<00:00,  9.83it/s]
#  83%|████████▎ | 40/48 [00:03<00:00,  9.75it/s]
#  85%|████████▌ | 41/48 [00:04<00:00,  9.49it/s]
#  88%|████████▊ | 42/48 [00:04<00:00,  9.45it/s]
#  90%|████████▉ | 43/48 [00:04<00:00,  9.27it/s]
#  94%|█████████▍| 45/48 [00:04<00:00,  9.77it/s]
#  98%|█████████▊| 47/48 [00:04<00:00,  9.87it/s]
# 100%|██████████| 48/48 [00:04<00:00, 10.17it/s]
# computing the features for 48 videos...
# 100%|██████████| 1/1 [00:18<00:00, 18.93s/it]
# padding...
# writting preprocess/test/seq_0.tfrecord...

# %% [markdown]
# #### Now we fit the autoencoder using the tf records

# %% [markdown]
# We **read** the sequential TF record

# %%
def read_seqtfrecords(filepath, batch_size=4):
    
    """
    This function reads the sequential tf-records.
    """
    
    # we define our dict of features
    context_features = dict()
    context_features["videos"] = tf.io.FixedLenFeature([1], tf.string)
    context_features["targets"] = tf.io.FixedLenFeature([1], tf.string)
    context_features["labels"] = tf.io.FixedLenFeature([4], tf.int64) # If you change the number of label, you should change the index num
    
    sequence_features = dict()
    sequence_features["embeddings"] = tf.io.FixedLenSequenceFeature([2048], tf.float32)
    
    # we define the parser
    def customized_parser(record, context_features, sequence_features):
        parsed = tf.io.parse_single_sequence_example(serialized=record, 
                                                     context_features=context_features,
                                                     sequence_features=sequence_features)
        
        return parsed

    def tfrecord_dataset(filepath):
        buffer_size = 8 * 1024 * 1024
        return tf.data.TFRecordDataset(filepath, buffer_size=buffer_size)

    # we list all the tf records files in the filepath folder
    files = tf.data.Dataset.list_files(filepath + "/*.tfrecord")
    dataset = files.apply(
        tf.data.experimental.parallel_interleave(
            tfrecord_dataset, cycle_length=8, sloppy=True
        )
    )
    
    # we read the files (parallelized)
    dataset = dataset.map(
        lambda record: customized_parser(record, context_features, sequence_features),
        num_parallel_calls=8,
    )

    dataset = dataset.batch(batch_size)
    dataset = dataset.repeat()
    dataset = dataset.prefetch(4)

    #training_iterator = dataset.make_one_shot_iterator()

   # next_element = training_iterator.get_next()
    iterator = iter(dataset)
    next_element = iterator.get_next()
    

    return next_element

# %%
batch_size = 16

sample = read_seqtfrecords("preprocess/train", batch_size)

sample[1]["embeddings"].shape
# Out:
# TensorShape([16, 10, 2048])

# %%
timesteps = sample[1]["embeddings"].shape[1]
n_features = sample[1]["embeddings"].shape[2]

# %% [markdown]
# we build our **LSTM auto encoder**. We need to **mask the 0-padding** for the reconstruction error

# %%
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import GRU
from keras.layers import SimpleRNN
from keras.layers import Dense, Masking
from keras.layers import RepeatVector
from keras.layers import TimeDistributed
from keras.models import Model

# %%
# define model
dim = 2048 

model = Sequential()
model.add(Masking(mask_value=0., input_shape=(timesteps, n_features)))
model.add(LSTM(dim, activation='relu'))
#model.add(LSTM(dim, activation='relu', input_shape=(timesteps, n_features)))
model.add(RepeatVector(timesteps))
model.add(LSTM(dim, activation='relu', return_sequences=True))
model.add(TimeDistributed(Dense(n_features)))
model.compile(optimizer='adam', loss='mse')
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# masking_1 (Masking)          (None, 10, 2048)          0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 2048)              33562624
# _________________________________________________________________
# repeat_vector_1 (RepeatVecto (None, 10, 2048)          0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 10, 2048)          33562624
# _________________________________________________________________
# time_distributed_1 (TimeDist (None, 10, 2048)          4196352
# =================================================================
# Total params: 71,321,600
# Trainable params: 71,321,600
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# we **fit** the auto encoder and then **remove the decoder part**

# %% [markdown]
# **[DO NOT RUN LOCALLY]**

# %%
epochs = 10
n_batch = int(dataset["train"].shape[0]/batch_size)+1

model.fit(x=sample[1]["embeddings"], 
          y=sample[1]["embeddings"], 
          steps_per_epoch=n_batch,
          epochs=epochs)
# Out:
# Epoch 1/10
# 8/8 [==============================] - 12s 1s/step - loss: 6461.0782
# Epoch 2/10
# 8/8 [==============================] - 11s 1s/step - loss: 82.6867
# Epoch 3/10
# 8/8 [==============================] - 11s 1s/step - loss: 2.0063
# Epoch 4/10
# 8/8 [==============================] - 11s 1s/step - loss: 0.5868
# Epoch 5/10
# 8/8 [==============================] - 11s 1s/step - loss: 0.3218
# Epoch 6/10
# 8/8 [==============================] - 11s 1s/step - loss: 0.1979
# Epoch 7/10
# 8/8 [==============================] - 11s 1s/step - loss: 0.1654
# Epoch 8/10
# 8/8 [==============================] - 11s 1s/step - loss: 0.1536
# Epoch 9/10
# 8/8 [==============================] - 11s 1s/step - loss: 0.1488
# Epoch 10/10
# 8/8 [==============================] - 11s 1s/step - loss: 0.1466

# %%
model = Model(inputs=model.inputs, outputs=model.layers[1].output)

# %%
# model.save_weights('lstm-ae.h5')

# %% [markdown]
# we **encode** some samples

# %%
# model.load_weights('lstm-ae.h5')

# %%
n_sample = 160

sample = read_seqtfrecords("preprocess/train", n_sample)

X = model.predict(x=sample[1]["embeddings"], 
                  steps = 1)

# %%
X.shape
# Out:
# (160, 2048)

# %% [markdown]
# #### 2D projection of representation

# %% [markdown]
# We got a new 1D-tensor representation for each video, so we can display it... (like in the previous section)

# %%
from sklearn.manifold import TSNE
from sklearn.neighbors import NearestNeighbors
import matplotlib.pyplot as plt

tsne = TSNE(n_components=2)

X_tnse = tsne.fit_transform(X)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 7))

classes = np.unique(sample[0]["targets"])

for c in classes:
    i = np.where(sample[0]["targets"]==c)[0]
    plt.plot(X_tnse[i,0], X_tnse[i,1], 'o')

# %% [markdown]
# #### Consistency and relevance

# %% [markdown]
# For a given random video, we check **if the nearest videos are similar**

# %%
nn = NearestNeighbors()
nn.fit(X)
# Out:
# NearestNeighbors()

# %% [markdown]
# we choose a random video:

# %%
from IPython.display import Image

v = np.random.choice(len(sample[0]["videos"]), 1)[0]
video_name = np.array(sample[0]["videos"])[v][0].decode("utf-8")

img = train[train.videos==video_name].frames.iloc[0][0]

print(video_name)
Image(img)
# Out:
# Data/v_4th_Expert_2_4.mp4

# %% [markdown]
# we compute the neighbors:

# %%
neighbors = nn.kneighbors([X[v]])[1][0][1:]

# %% [markdown]
# we display the nearest video:

# %%
neigh1 = np.array(sample[0]["videos"])[neighbors[0]][0].decode("utf-8")

print(neigh1)
img = train[train.videos==neigh1].frames.iloc[0][0]
Image(img)
# Out:
# Data/v_4th_Expert_2_4.mp4

# %% [markdown]
# we check the categories of the top-4 nearest videos:

# %%
for i in neighbors:
    print(np.array(sample[0]["videos"])[i][0].decode("utf-8"))
# Out:
# Data/v_4th_Expert_2_4.mp4
# Data/v_4th_Novice_2_3.mp4
# Data/v_4th_Novice_2_3.mp4
# Data/v_4th_Novice_2_6.mp4

# %% [markdown]
# **we compute top1 & top2 accuracy**

# %%
a1 = 0
a2 = 0
n = len(sample[0]["videos"])

for v in range(len(sample[0]["videos"])):
    
    video_name = np.array(sample[0]["videos"])[v][0].decode("utf-8")
    category = train[train.videos==video_name].targets.iloc[0]
    
    neighbors = nn.kneighbors([X[v]])[1][0][1:] 
    
    neigh1 = np.array(sample[0]["videos"])[neighbors[0]][0].decode("utf-8")
    neigh2 = np.array(sample[0]["videos"])[neighbors[1]][0].decode("utf-8")
    
    category1 = train[train.videos==neigh1].targets.iloc[0]
    category2 = train[train.videos==neigh2].targets.iloc[0]

    if category==category1:
        a1+=1/n
    if category==category1 or category==category2:
        a2+=1/n

# %%
print("top1-accuracy", a1)
print("top2-accuracy", a2)
# Out:
# top1-accuracy 0.9687499999999976
# top2-accuracy 0.9749999999999975

# %% [markdown]
# # 4. Supervised learning: video classification

# %% [markdown]
# The purpose of this section is to **automatically classify** videos. We will try (only) 2 different approaches: **average pooling** & **LSTM**. There exists a lot of different RNN architectures, which can be easily tested by adapting the following code...

# %% [markdown]
# #### we read the TF records

# %%
batch_size = 4

train_sample = read_seqtfrecords("preprocess/train", batch_size)
test_sample = read_seqtfrecords("preprocess/test", batch_size)

timesteps = train_sample[1]["embeddings"].shape[1]
n_features = train_sample[1]["embeddings"].shape[2]
n_classes = train_sample[0]["labels"].shape[1]

n_batch = int(dataset["train"].shape[0]/batch_size)+1

# %% [markdown]
# ## 4.a. Average pooling

# %% [markdown]
# We just **average** the frames features.

# %%
from keras.layers import AveragePooling1D, MaxPooling1D, Reshape

# %% [markdown]
# model compilation

# %%
model = Sequential()
model.add(AveragePooling1D(pool_size=timesteps, padding="valid", data_format='channels_last', input_shape=(timesteps, n_features)))
model.add(Reshape((n_features,), input_shape=(-1,1, n_features)))
model.add(Dense(n_classes, activation="softmax"))
model.compile(optimizer='adam', loss="categorical_crossentropy", metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# average_pooling1d_1 (Average (None, 1, 2048)           0
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 2048)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 4)                 8196
# =================================================================
# Total params: 8,196
# Trainable params: 8,196
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# fitting the model

# %%
epochs = 5

model.fit(x=train_sample[1]["embeddings"], 
          y=train_sample[0]["labels"], 
          validation_data = (test_sample[1]["embeddings"], test_sample[0]["labels"]), 
          steps_per_epoch=n_batch, 
          validation_steps=10, 
          epochs=epochs)
# Out:
# Train on 4 samples, validate on 4 samples
# Epoch 1/5
# 29/29 [==============================] - 0s 5ms/step - loss: 0.3327 - accuracy: 0.8707 - val_loss: 0.7708 - val_accuracy: 5.0000
# Epoch 2/5
# 29/29 [==============================] - 0s 768us/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.8142 - val_accuracy: 5.0000
# Epoch 3/5
# 29/29 [==============================] - 0s 804us/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.8144 - val_accuracy: 5.0000
# Epoch 4/5
# 29/29 [==============================] - 0s 858us/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.8131 - val_accuracy: 5.0000
# Epoch 5/5
# 29/29 [==============================] - 0s 828us/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.8114 - val_accuracy: 5.0000

# %% [markdown]
# model evaluation

# %%
model.evaluate(x=test_sample[1]["embeddings"],
               y=test_sample[0]["labels"],
               steps=10)
# Out:
# 10/10 [==============================] - 0s 444us/step
# [0.8114409446716309, 5.0]

# %% [markdown]
# model prediction

# %%
model.predict(x=test_sample[1]["embeddings"], 
              steps=1)
# Out:
# array([[4.5044183e-07, 9.9518651e-08, 2.2617069e-01, 7.7382874e-01],
#        [2.0521746e-07, 7.6618520e-08, 2.1630978e-02, 9.7836876e-01],
#        [9.6473435e-08, 1.9538964e-08, 9.5279109e-01, 4.7208857e-02],
#        [6.8324283e-08, 8.1854248e-09, 9.3064576e-01, 6.9354132e-02]],
#       dtype=float32)

# %% [markdown]
# ## 4.b. RNN : LSTM

# %% [markdown]
# We try LSTM Recurrent Neural Network.

# %% [markdown]
# model compilation

# %%
dim = 20  # can be fine-tuned...

model = Sequential()
model.add(Masking(mask_value=0., input_shape=(timesteps, n_features)))
model.add(SimpleRNN(dim, activation='relu'))
#model.add(LSTM(dim, activation='relu', input_shape=(timesteps, n_features)))
model.add(Dense(n_classes, activation="softmax"))
model.compile(optimizer='adam', loss="categorical_crossentropy", metrics=['accuracy','top_k_categorical_accuracy'])
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# masking_2 (Masking)          (None, 10, 2048)          0
# _________________________________________________________________
# simple_rnn_1 (SimpleRNN)     (None, 20)                41380
# _________________________________________________________________
# dense_3 (Dense)              (None, 4)                 84
# =================================================================
# Total params: 41,464
# Trainable params: 41,464
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# fitting the model

# %% [markdown]
# **[DO NOT RUN LOCALLY]**

# %%
epochs = 3

model.fit(x=train_sample[1]["embeddings"], 
          y=train_sample[0]["labels"], 
          validation_data = (test_sample[1]["embeddings"], test_sample[0]["labels"]), 
          steps_per_epoch=n_batch, 
          validation_steps=5, 
          epochs=epochs)
# Out:
# Train on 4 samples, validate on 4 samples
# Epoch 1/3
# 29/29 [==============================] - 0s 9ms/step - loss: 0.1150 - accuracy: 0.9569 - top_k_categorical_accuracy: 1.0000 - val_loss: 2.3156 - val_accuracy: 1.2500 - val_top_k_categorical_accuracy: 5.0000
# Epoch 2/3
# 29/29 [==============================] - 0s 3ms/step - loss: 1.0171e-05 - accuracy: 1.0000 - top_k_categorical_accuracy: 1.0000 - val_loss: 2.3658 - val_accuracy: 2.5000 - val_top_k_categorical_accuracy: 5.0000
# Epoch 3/3
# 29/29 [==============================] - 0s 3ms/step - loss: 1.1674e-06 - accuracy: 1.0000 - top_k_categorical_accuracy: 1.0000 - val_loss: 2.3615 - val_accuracy: 2.5000 - val_top_k_categorical_accuracy: 5.0000

# %%
# model.save_weights('lstm.h5')

# %% [markdown]
# model evaluation

# %%
# model.load_weights('lstm.h5')

# %%
model.evaluate(x=test_sample[1]["embeddings"],
               y=test_sample[0]["labels"],
               steps=10)
# Out:
# 10/10 [==============================] - 0s 931us/step
# [1.1807384490966797, 5.0, 10.0]

# %% [markdown]
# model prediction

# %%
model.predict(x=test_sample[1]["embeddings"], 
              steps=1)
# Out:
# array([[9.7646778e-12, 8.9606075e-08, 6.8894535e-01, 3.1105456e-01],
#        [1.6026520e-10, 6.2007786e-08, 2.8561530e-01, 7.1438462e-01],
#        [3.5784022e-14, 4.4183418e-10, 9.9998307e-01, 1.6909735e-05],
#        [5.1279442e-15, 5.5408594e-10, 9.9913090e-01, 8.6909736e-04]],
#       dtype=float32)
